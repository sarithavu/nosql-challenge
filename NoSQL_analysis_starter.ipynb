# %% [markdown]
# # Eat Safe, Love

# %% [markdown]
# ## Notebook Set Up

# %%
from pymongo import MongoClient
import pandas as pd
from pprint import pprint

# %%
# Create an instance of MongoClient
mongo = MongoClient(port=27017)

# %%
# assign the uk_food database to a variable name
db = mongo['uk_food']

# %%
# review the collections in our database
print(db.list_collection_names())
# Out:
# ['establishments']

# %%
# assign the collection to a variable
establishments = db['establishments']

# %% [markdown]
# ## Part 3: Exploratory Analysis
# Unless otherwise stated, for each question:
# * Use `count_documents` to display the number of documents contained in the result.
# * Display the first document in the results using `pprint`.
# * Convert the result to a Pandas DataFrame, print the number of rows in the DataFrame, and display the first 10 rows.

# %% [markdown]
# ### 1. Which establishments have a hygiene score equal to 20?

# %%
establishments.find_one()
# Out:
# {'_id': ObjectId('664e9e0110d09d5d76f955f7'),
#  'FHRSID': 1043695,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': 'PI/000073616',
#  'BusinessName': 'The Pavilion',
#  'BusinessType': 'Restaurant/Cafe/Canteen',
#  'BusinessTypeID': 1,
#  'AddressLine1': 'East Cliff Pavilion',
#  'AddressLine2': 'Wear Bay Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'PostCode': 'CT19 6BL',
#  'Phone': '',
#  'RatingValue': 5,
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingDate': '2018-04-04T00:00:00',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'scores': {'Hygiene': 5, 'Structural': 5, 'ConfidenceInManagement': 5},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '1.195625', 'latitude': '51.083812'},
#  'RightToReply': '',
#  'Distance': 4591.765489457773,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/1043695'}],
#  'latitude': 51.083812,
#  'longitude': 1.195625}

# %%
# Query to find establishments with a hygiene score of 20
query = establishments.find_one({'scores.Hygiene': 20})
query
# Out:
# {'_id': ObjectId('664e9e0110d09d5d76f9713c'),
#  'FHRSID': 110681,
#  'ChangesByServerID': 0,
#  'LocalAuthorityBusinessID': '4029',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'PostCode': 'BN21 1BU',
#  'Phone': '',
#  'RatingValue': 0,
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingDate': '2021-09-23T00:00:00',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'scores': {'Hygiene': 20, 'Structural': 20, 'ConfidenceInManagement': 20},
#  'SchemeType': 'FHRS',
#  'geocode': {'longitude': '0.27694', 'latitude': '50.769705'},
#  'RightToReply': '',
#  'Distance': 4613.888288172291,
#  'NewRatingPending': False,
#  'meta': {'dataSource': None,
#   'extractDate': '0001-01-01T00:00:00',
#   'itemCount': 0,
#   'returncode': None,
#   'totalCount': 0,
#   'totalPages': 0,
#   'pageSize': 0,
#   'pageNumber': 0},
#  'links': [{'rel': 'self',
#    'href': 'https://api.ratings.food.gov.uk/establishments/110681'}],
#  'latitude': 50.769705,
#  'longitude': 0.27694}

# %%
# Count the number of documents with a hygiene score of 20
count = establishments.count_documents({'scores.Hygiene': 20})
count
# Out:
# 41

# %%
# Display the first document in the results using pprint
#result = establishments.find_one({'scores.Hygiene': 20})
pprint(query)
# Out:
# {'AddressLine1': '5-6 Southfields Road',
#  'AddressLine2': 'Eastbourne',
#  'AddressLine3': 'East Sussex',
#  'AddressLine4': '',
#  'BusinessName': 'The Chase Rest Home',
#  'BusinessType': 'Caring Premises',
#  'BusinessTypeID': 5,
#  'ChangesByServerID': 0,
#  'Distance': 4613.888288172291,
#  'FHRSID': 110681,
#  'LocalAuthorityBusinessID': '4029',
#  'LocalAuthorityCode': '102',
#  'LocalAuthorityEmailAddress': 'Customerfirst@eastbourne.gov.uk',
#  'LocalAuthorityName': 'Eastbourne',
#  'LocalAuthorityWebSite': 'http://www.eastbourne.gov.uk/foodratings',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'BN21 1BU',
#  'RatingDate': '2021-09-23T00:00:00',
#  'RatingKey': 'fhrs_0_en-gb',
#  'RatingValue': 0,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f9713c'),
#  'geocode': {'latitude': '50.769705', 'longitude': '0.27694'},
#  'latitude': 50.769705,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/110681',
#             'rel': 'self'}],
#  'longitude': 0.27694,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 20, 'Hygiene': 20, 'Structural': 20}}

# %%
# Convert the result to a Pandas DataFrame
result_df = pd.DataFrame(establishments.find({'scores.Hygiene': 20}))
result_df.head()
# Out:
#                         _id  FHRSID  ChangesByServerID  \
# 0  664e9e0110d09d5d76f9713c  110681                  0
# 1  664e9e0110d09d5d76f974b5  612039                  0
# 2  664e9e0110d09d5d76f977b6  730933                  0
# 3  664e9e0110d09d5d76f9799f  172735                  0
# 4  664e9e0110d09d5d76f979c5  172953                  0
#
#   LocalAuthorityBusinessID         BusinessName  \
# 0                     4029  The Chase Rest Home
# 1                1970/FOOD           Brenalwood
# 2                1698/FOOD        Melrose Hotel
# 3             PI/000023858        Seaford Pizza
# 4             PI/000024532        Golden Palace
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links   latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  50.769705  0.276940
# 1  [{'rel': 'self', 'href': 'https://api.ratings....  51.857536  1.278721
# 2  [{'rel': 'self', 'href': 'https://api.ratings....  51.789429  1.159270
# 3  [{'rel': 'self', 'href': 'https://api.ratings....  50.770885  0.102020
# 4  [{'rel': 'self', 'href': 'https://api.ratings....  50.770724  0.101446
#
# [5 rows x 30 columns]

# %%
# Display the number of rows in the DataFrame
len(result_df )
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  664e9e0110d09d5d76f9713c   110681                  0
# 1  664e9e0110d09d5d76f974b5   612039                  0
# 2  664e9e0110d09d5d76f977b6   730933                  0
# 3  664e9e0110d09d5d76f9799f   172735                  0
# 4  664e9e0110d09d5d76f979c5   172953                  0
# 5  664e9e0110d09d5d76f9835c   512854                  0
# 6  664e9e0110d09d5d76f98572  1537089                  0
# 7  664e9e0110d09d5d76f99a9d   155648                  0
# 8  664e9e0110d09d5d76f99ee0  1012883                  0
# 9  664e9e0210d09d5d76f9a6f3   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links   latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  50.769705  0.276940
# 1  [{'rel': 'self', 'href': 'https://api.ratings....  51.857536  1.278721
# 2  [{'rel': 'self', 'href': 'https://api.ratings....  51.789429  1.159270
# 3  [{'rel': 'self', 'href': 'https://api.ratings....  50.770885  0.102020
# 4  [{'rel': 'self', 'href': 'https://api.ratings....  50.770724  0.101446
# 5  [{'rel': 'self', 'href': 'https://api.ratings....  51.541448  0.736349
# 6  [{'rel': 'self', 'href': 'https://api.ratings....  51.535007  0.712167
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.591515  0.602364
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.185947  0.146450
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.570050  0.462307
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 2. Which establishments in London have a `RatingValue` greater than or equal to 4?

# %%
# Find the establishments with London as the Local Authority and has a RatingValue greater than or equal to 4.
# Use count_documents to display the number of documents in the result
# Display the first document in the results using pprint
query = {'LocalAuthorityName': {'$regex': 'London'} , 'RatingValue': {"$gte": 4}}
results = establishments.find(query)
pprint(results[0])
establishments.count_documents(query)
# Out:
# {'AddressLine1': 'Oak Apple Farm Building 103 Sheernes Docks',
#  'AddressLine2': 'Sheppy Kent',
#  'AddressLine3': '',
#  'AddressLine4': '',
#  'BusinessName': "Charlie's",
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4627.439467780196,
#  'FHRSID': 621707,
#  'LocalAuthorityBusinessID': 'PI/000025307',
#  'LocalAuthorityCode': '508',
#  'LocalAuthorityEmailAddress': 'publicprotection@cityoflondon.gov.uk',
#  'LocalAuthorityName': 'City of London Corporation',
#  'LocalAuthorityWebSite': 'http://www.cityoflondon.gov.uk/Corporation/homepage.htm',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'ME12',
#  'RatingDate': '2021-10-18T00:00:00',
#  'RatingKey': 'fhrs_4_en-gb',
#  'RatingValue': 4,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f98b44'),
#  'geocode': {'latitude': '51.369321', 'longitude': '0.508551'},
#  'latitude': 51.369321,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/621707',
#             'rel': 'self'}],
#  'longitude': 0.508551,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 5, 'Structural': 10}}
# 33

# %%
results_df = pd.DataFrame(results)
results_df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   664e9e0110d09d5d76f98b44   621707                  0
# 1   664e9e0110d09d5d76f98e68  1130836                  0
# 2   664e9e0110d09d5d76f999b7   293783                  0
# 3   664e9e0210d09d5d76f9a7b5  1315095                  0
# 4   664e9e0210d09d5d76f9a7b7   294474                  0
# 5   664e9e0210d09d5d76f9aec0   294900                  0
# 6   664e9e0210d09d5d76f9cfd2   293756                  0
# 7   664e9e0210d09d5d76f9d394   878523                  0
# 8   664e9e0210d09d5d76f9d3b0   293772                  0
# 9   664e9e0210d09d5d76f9d3b1   294606                  0
# 10  664e9e0210d09d5d76f9d3b2   295107                  0
# 11  664e9e0210d09d5d76f9d58d   294523                  0
# 12  664e9e0210d09d5d76f9d591   294616                  0
# 13  664e9e0210d09d5d76f9d831  1427985                  0
# 14  664e9e0210d09d5d76f9da3b   934211                  0
# 15  664e9e0210d09d5d76f9da61  1392440                  0
# 16  664e9e0210d09d5d76f9da66   558640                  0
# 17  664e9e0210d09d5d76f9dc27  1498024                  0
# 18  664e9e0210d09d5d76f9dc74  1090017                  0
# 19  664e9e0210d09d5d76f9dc76  1090023                  0
# 20  664e9e0210d09d5d76f9dc77  1090021                  0
# 21  664e9e0210d09d5d76f9dc78  1090022                  0
# 22  664e9e0210d09d5d76f9dc79  1090020                  0
# 23  664e9e0210d09d5d76f9dc7a  1090027                  0
# 24  664e9e0210d09d5d76f9dc7b  1090019                  0
# 25  664e9e0210d09d5d76f9dc7c  1090018                  0
# 26  664e9e0210d09d5d76f9dc7d  1090025                  0
# 27  664e9e0210d09d5d76f9dc7e  1090028                  0
# 28  664e9e0210d09d5d76f9dc7f  1090024                  0
# 29  664e9e0210d09d5d76f9dc80  1090026                  0
# 30  664e9e0210d09d5d76f9dc81  1090016                  0
# 31  664e9e0210d09d5d76f9dc82   293758                  0
# 32  664e9e0210d09d5d76f9dc83  1450220                  0
#
#    LocalAuthorityBusinessID                          BusinessName  \
# 0              PI/000025307                             Charlie's
# 1              PI/000034075               Mv City Cruises Erasmus
# 2              PI/000002614             Benfleet Motor Yacht Club
# 3              PI/000036464  Coombs Catering t/a The Lock and Key
# 4              PI/000014647              Tilbury Seafarers Centre
# 5              PI/000019066                            Mv Valulla
# 6              PI/000002538                         Tereza Joanne
# 7              PI/000029844                      Brick Lane Brews
# 8              PI/000002585         The Nuance Group (UK) Limited
# 9              PI/000016185                              WH Smith
# 10             PI/000020749                      City Bar & Grill
# 11             PI/000015222                            Jet Centre
# 12             PI/000016269                            Caffè Nero
# 13             PI/000037871                Mv Sunborn Yacht Hotel
# 14             PI/000030457                     Good Hotel London
# 15             PI/000037382                         La Nonna lina
# 16             PI/000024155             Wake Up Docklands Limited
# 17             PI/000038347                      MV Venus Clipper
# 18             PI/000033472                       MV Moon clipper
# 19             PI/000033479                    MV Jupiter clipper
# 20             PI/000033477                    MV Monsoon clipper
# 21             PI/000033478                     MV Meteor clipper
# 22             PI/000033476                    MV Typhoon clipper
# 23             PI/000033483                    MV Cyclone clipper
# 24             PI/000033475                    MV Tornado clipper
# 25             PI/000033473                    MV Mercury clipper
# 26             PI/000033481                  MV Hurricane clipper
# 27             PI/000033484                    MV Neptune clipper
# 28             PI/000033480                     MV Galaxy clipper
# 29             PI/000033482                     MV Aurora clipper
# 30             PI/000033470                        MV Sun clipper
# 31             PI/000002546                      Mv Storm Clipper
# 32             PI/000038259                       Canary Wharf 1V
#
#                          BusinessType  BusinessTypeID  \
# 0             Other catering premises            7841
# 1             Other catering premises            7841
# 2             Other catering premises            7841
# 3             Restaurant/Cafe/Canteen               1
# 4             Restaurant/Cafe/Canteen               1
# 5             Other catering premises            7841
# 6             Other catering premises            7841
# 7             Restaurant/Cafe/Canteen               1
# 8                   Retailers - other            4613
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Restaurant/Cafe/Canteen               1
# 12            Restaurant/Cafe/Canteen               1
# 13  Hotel/bed & breakfast/guest house            7842
# 14            Other catering premises            7841
# 15            Other catering premises            7841
# 16            Other catering premises            7841
# 17            Other catering premises            7841
# 18            Other catering premises            7841
# 19            Other catering premises            7841
# 20            Other catering premises            7841
# 21            Other catering premises            7841
# 22            Other catering premises            7841
# 23            Other catering premises            7841
# 24            Other catering premises            7841
# 25            Other catering premises            7841
# 26            Other catering premises            7841
# 27            Other catering premises            7841
# 28            Other catering premises            7841
# 29            Other catering premises            7841
# 30            Other catering premises            7841
# 31            Other catering premises            7841
# 32            Other catering premises            7841
#
#                                          AddressLine1  \
# 0          Oak Apple Farm Building 103 Sheernes Docks
# 1                                  Cherry Garden Pier
# 2                                          Ferry Road
# 3                                   Leslie Ford House
# 4                           Tenants Row Tilbury Docks
# 5   Reeds River Cruises LtdKings ReachRiver Thames...
# 6   Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                        Air side London City Airport
# 8                   Duty Free Shop Passenger Terminal
# 9                                 London City Airport
# 10                      London City Airport (Airside)
# 11                                London City Airport
# 12       London City Airport Airside Departure Lounge
# 13                                    Western Gateway
# 14                Western Gateway Royal Victoria Dock
# 15                                          Dock Road
# 16                 Western Beach Royal Victoria Docks
# 17                                 Trinity Buoy Wharf
# 18             Thames Clippers 3rd flr Clippers House
# 19     Thames Clippers Unit 12 The Riverside Building
# 20     Thames Clippers Unit 12 The Riverside Building
# 21     Thames Clippers Unit 12 The Riverside Building
# 22     Thames Clippers Unit 12 The Riverside Building
# 23     Thames Clippers Unit 12 The Riverside Building
# 24     Thames Clippers Unit 12 The Riverside Building
# 25             Thames Clippers 3rd flr Clippers House
# 26     Thames Clippers Unit 12 The Riverside Building
# 27     Thames Clippers Unit 12 The Riverside Building
# 28     Thames Clippers Unit 12 The Riverside Building
# 29     Thames Clippers Unit 12 The Riverside Building
# 30             Thames Clippers 3rd flr Clippers House
# 31     Thames Clippers Unit 12 The Riverside Building
# 32                                 Trinity Buoy Wharf
#
#                                     AddressLine2 AddressLine3  ...  \
# 0                                    Sheppy Kent               ...
# 1               Cherry Garden Street Rotherhithe     Charlton  ...
# 2                           South Benfleet Essex               ...
# 3                                        Tilbury     Charlton  ...
# 4                                  Tilbury Essex               ...
# 5                                         London               ...
# 6                                         London               ...
# 7                                         London               ...
# 8           London City AirportRoyal DocksLondon               ...
# 9                              Silvertown London               ...
# 10                                        London               ...
# 11                            Royal Docks London               ...
# 12                            Royal Docks London               ...
# 13                           Royal Victoria Dock               ...
# 14  Floating Platform next to Emirates Cable Car               ...
# 15                                        London     Charlton  ...
# 16                                        London     Charlton  ...
# 17                                 Orchard Place               ...
# 18       Orchard Place Trinity Buoy Wharf London               ...
# 19    64 Orchard Place Trinity Buoy Wharf London               ...
# 20    64 Orchard Place Trinity Buoy Wharf London               ...
# 21    64 Orchard Place Trinity Buoy Wharf London               ...
# 22    64 Orchard Place Trinity Buoy Wharf London               ...
# 23    64 Orchard Place Trinity Buoy Wharf London               ...
# 24    64 Orchard Place Trinity Buoy Wharf London               ...
# 25       Orchard Place Trinity Buoy Wharf London               ...
# 26    64 Orchard Place Trinity Buoy Wharf London               ...
# 27    64 Orchard Place Trinity Buoy Wharf London               ...
# 28    64 Orchard Place Trinity Buoy Wharf London               ...
# 29    64 Orchard Place Trinity Buoy Wharf London               ...
# 30       Orchard Place Trinity Buoy Wharf London               ...
# 31    64 Orchard Place Trinity Buoy Wharf London               ...
# 32                              64 Orchard Place               ...
#
#                                                scores SchemeType  \
# 0   {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6   {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7   {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9   {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 10  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 11  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 12  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 13  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 14  {'Hygiene': 5, 'Structural': 5, 'ConfidenceInM...       FHRS
# 15  {'Hygiene': 0, 'Structural': 10, 'ConfidenceIn...       FHRS
# 16  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 17  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 18  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 19  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 20  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 21  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 22  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 23  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 24  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 25  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 26  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 27  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 28  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 29  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 30  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 31  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 32  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                               geocode  RightToReply  \
# 0   {'longitude': '0.508551', 'latitude': '51.3693...
# 1   {'longitude': '0.249255999922752', 'latitude':...
# 2   {'longitude': '0.561954', 'latitude': '51.5438...
# 3   {'longitude': '0.346336990594864', 'latitude':...
# 4   {'longitude': '0.346325', 'latitude': '51.4640...
# 5   {'longitude': '0.287555', 'latitude': '51.5040...
# 6   {'longitude': '0.069286', 'latitude': '51.5011...
# 7   {'longitude': '0.048006', 'latitude': '51.5037...
# 8   {'longitude': '0.047966', 'latitude': '51.5041...
# 9   {'longitude': '0.0479655750095844', 'latitude'...
# 10  {'longitude': '0.0479655750095844', 'latitude'...
# 11  {'longitude': '0.0405181497335434', 'latitude'...
# 12  {'longitude': '0.040518', 'latitude': '51.5048...
# 13  {'longitude': '0.027107', 'latitude': '51.50817'}
# 14  {'longitude': '0.01792', 'latitude': '51.507681'}
# 15  {'longitude': '0.0157549995929003', 'latitude'...
# 16  {'longitude': '0.015742', 'latitude': '51.5059...
# 17  {'longitude': '0.00890800673629534', 'latitude...
# 18  {'longitude': '0.0078159999102354', 'latitude'...
# 19  {'longitude': '0.007816', 'latitude': '51.5082...
# 20  {'longitude': '0.007816', 'latitude': '51.5082...
# 21  {'longitude': '0.007816', 'latitude': '51.5082...
# 22  {'longitude': '0.007816', 'latitude': '51.5082...
# 23  {'longitude': '0.007816', 'latitude': '51.5082...
# 24  {'longitude': '0.007816', 'latitude': '51.5082...
# 25  {'longitude': '0.0078159999102354', 'latitude'...
# 26  {'longitude': '0.007816', 'latitude': '51.5082...
# 27  {'longitude': '0.007816', 'latitude': '51.5082...
# 28  {'longitude': '0.007816', 'latitude': '51.5082...
# 29  {'longitude': '0.007816', 'latitude': '51.5082...
# 30  {'longitude': '0.0078159999102354', 'latitude'...
# 31  {'longitude': '0.007816', 'latitude': '51.5082...
# 32  {'longitude': '0.007815', 'latitude': '51.5082...
#
#        Distance NewRatingPending  \
# 0   4627.439468            False
# 1   4627.873179            False
# 2   4631.968418            False
# 3   4636.846754            False
# 4   4636.847650            False
# 5   4640.460834            False
# 6   4648.301822            False
# 7   4649.173485            False
# 8   4649.188826            False
# 9   4649.188850            False
# 10  4649.188850            False
# 11  4649.485870            False
# 12  4649.485929            False
# 13  4650.098130            False
# 14  4650.415301            False
# 15  4650.432066            False
# 16  4650.432926            False
# 17  4650.747349            False
# 18  4650.805001            False
# 19  4650.805008            False
# 20  4650.805008            False
# 21  4650.805008            False
# 22  4650.805008            False
# 23  4650.805008            False
# 24  4650.805008            False
# 25  4650.805001            False
# 26  4650.805008            False
# 27  4650.805008            False
# 28  4650.805008            False
# 29  4650.805008            False
# 30  4650.805001            False
# 31  4650.805008            False
# 32  4650.805044            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links   latitude longitude
# 0   [{'rel': 'self', 'href': 'https://api.ratings....  51.369321  0.508551
# 1   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.123623  0.249256
# 2   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.543831  0.561954
# 3   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.464066  0.346337
# 4   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.464078  0.346325
# 5   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504071  0.287555
# 6   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.501121  0.069286
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.503733  0.048006
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504112  0.047966
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504112  0.047966
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504112  0.047966
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504807  0.040518
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504808  0.040518
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508170  0.027107
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.507681  0.017920
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.505981  0.015755
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.505992  0.015742
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.507772  0.008908
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007816
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.508259  0.007815
#
# [33 rows x 30 columns]

# %%
# Display the number of rows in the DataFrame
len(results_df)
# Out:
# 33

# %%
# Display the first 10 rows of the DataFrame
results_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  664e9e0110d09d5d76f98b44   621707                  0
# 1  664e9e0110d09d5d76f98e68  1130836                  0
# 2  664e9e0110d09d5d76f999b7   293783                  0
# 3  664e9e0210d09d5d76f9a7b5  1315095                  0
# 4  664e9e0210d09d5d76f9a7b7   294474                  0
# 5  664e9e0210d09d5d76f9aec0   294900                  0
# 6  664e9e0210d09d5d76f9cfd2   293756                  0
# 7  664e9e0210d09d5d76f9d394   878523                  0
# 8  664e9e0210d09d5d76f9d3b0   293772                  0
# 9  664e9e0210d09d5d76f9d3b1   294606                  0
#
#   LocalAuthorityBusinessID                          BusinessName  \
# 0             PI/000025307                             Charlie's
# 1             PI/000034075               Mv City Cruises Erasmus
# 2             PI/000002614             Benfleet Motor Yacht Club
# 3             PI/000036464  Coombs Catering t/a The Lock and Key
# 4             PI/000014647              Tilbury Seafarers Centre
# 5             PI/000019066                            Mv Valulla
# 6             PI/000002538                         Tereza Joanne
# 7             PI/000029844                      Brick Lane Brews
# 8             PI/000002585         The Nuance Group (UK) Limited
# 9             PI/000016185                              WH Smith
#
#               BusinessType  BusinessTypeID  \
# 0  Other catering premises            7841
# 1  Other catering premises            7841
# 2  Other catering premises            7841
# 3  Restaurant/Cafe/Canteen               1
# 4  Restaurant/Cafe/Canteen               1
# 5  Other catering premises            7841
# 6  Other catering premises            7841
# 7  Restaurant/Cafe/Canteen               1
# 8        Retailers - other            4613
# 9        Retailers - other            4613
#
#                                         AddressLine1  \
# 0         Oak Apple Farm Building 103 Sheernes Docks
# 1                                 Cherry Garden Pier
# 2                                         Ferry Road
# 3                                  Leslie Ford House
# 4                          Tenants Row Tilbury Docks
# 5  Reeds River Cruises LtdKings ReachRiver Thames...
# 6  Funcraft UK Ltd King George V Dock Woolwich Ma...
# 7                       Air side London City Airport
# 8                  Duty Free Shop Passenger Terminal
# 9                                London City Airport
#
#                            AddressLine2 AddressLine3  ...  \
# 0                           Sheppy Kent               ...
# 1      Cherry Garden Street Rotherhithe     Charlton  ...
# 2                  South Benfleet Essex               ...
# 3                               Tilbury     Charlton  ...
# 4                         Tilbury Essex               ...
# 5                                London               ...
# 6                                London               ...
# 7                                London               ...
# 8  London City AirportRoyal DocksLondon               ...
# 9                     Silvertown London               ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 5, 'Structural': 10, 'ConfidenceIn...       FHRS
# 1  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 2  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 3  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 5  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 6  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 7  {'Hygiene': 10, 'Structural': 5, 'ConfidenceIn...       FHRS
# 8  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
# 9  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.508551', 'latitude': '51.3693...
# 1  {'longitude': '0.249255999922752', 'latitude':...
# 2  {'longitude': '0.561954', 'latitude': '51.5438...
# 3  {'longitude': '0.346336990594864', 'latitude':...
# 4  {'longitude': '0.346325', 'latitude': '51.4640...
# 5  {'longitude': '0.287555', 'latitude': '51.5040...
# 6  {'longitude': '0.069286', 'latitude': '51.5011...
# 7  {'longitude': '0.048006', 'latitude': '51.5037...
# 8  {'longitude': '0.047966', 'latitude': '51.5041...
# 9  {'longitude': '0.0479655750095844', 'latitude'...
#
#       Distance NewRatingPending  \
# 0  4627.439468            False
# 1  4627.873179            False
# 2  4631.968418            False
# 3  4636.846754            False
# 4  4636.847650            False
# 5  4640.460834            False
# 6  4648.301822            False
# 7  4649.173485            False
# 8  4649.188826            False
# 9  4649.188850            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links   latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  51.369321  0.508551
# 1  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.123623  0.249256
# 2  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.543831  0.561954
# 3  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.464066  0.346337
# 4  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.464078  0.346325
# 5  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504071  0.287555
# 6  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.501121  0.069286
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.503733  0.048006
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504112  0.047966
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.504112  0.047966
#
# [10 rows x 30 columns]

# %% [markdown]
# ### 3. What are the top 5 establishments with a `RatingValue` rating value of 5, sorted by lowest hygiene score, nearest to the new restaurant added, "Penang Flavours"?

# %%
# Search within 0.01 degree on either side of the latitude and longitude.
# Rating value must equal 5
# Sort by hygiene score

degree_search = 0.01
latitude = 51.083812
longitude = 1.195625

query = {
    'latitude': {'$gte': latitude - degree_search, '$lte': latitude + degree_search},
    'longitude': {'$gte': longitude - degree_search, '$lte': longitude + degree_search},
    'RatingValue': 5
}

sort = [('scores.Hygiene', 1)]
limit = 5

results = establishments.find(query).sort(sort).limit(limit)

for result in results:
    pprint(result)
# Out:
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Little Rock',
#  'BusinessType': 'Other catering premises',
#  'BusinessTypeID': 7841,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 1423242,
#  'LocalAuthorityBusinessID': 'PI/000078141',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2022-04-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f95609'),
#  'geocode': {'latitude': '51.0783519967076', 'longitude': '1.18590330311705'},
#  'latitude': 51.0783519967076,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/1423242',
#             'rel': 'self'}],
#  'longitude': 1.18590330311705,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '42 North Street',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'The Lifeboat',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4592.005041613854,
#  'FHRSID': 511409,
#  'LocalAuthorityBusinessID': 'PI/000039931',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AF',
#  'RatingDate': '2020-07-22T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f95640'),
#  'geocode': {'latitude': '51.081546', 'longitude': '1.186715'},
#  'latitude': 51.081546,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/511409',
#             'rel': 'self'}],
#  'longitude': 1.186715,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': None,
#             'Hygiene': None,
#             'Structural': None}}
# {'AddressLine1': '1 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Folkestone Trawlers Shop',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 344689,
#  'LocalAuthorityBusinessID': 'PI/000002095',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2020-02-14T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f955fe'),
#  'geocode': {'latitude': '51.08084', 'longitude': '1.188537'},
#  'latitude': 51.08084,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/344689',
#             'rel': 'self'}],
#  'longitude': 1.188537,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': '16 The Stade',
#  'AddressLine2': 'Folkestone',
#  'AddressLine3': 'Kent',
#  'AddressLine4': '',
#  'BusinessName': 'Mariner',
#  'BusinessType': 'Pub/bar/nightclub',
#  'BusinessTypeID': 7843,
#  'ChangesByServerID': 0,
#  'Distance': 4591.912144538092,
#  'FHRSID': 289560,
#  'LocalAuthorityBusinessID': 'PI/000039927',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': 'CT19 6AB',
#  'RatingDate': '2019-03-19T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f955ff'),
#  'geocode': {'latitude': '51.08084', 'longitude': '1.188537'},
#  'latitude': 51.08084,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/289560',
#             'rel': 'self'}],
#  'longitude': 1.188537,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 0, 'Hygiene': 0, 'Structural': 5}}
# {'AddressLine1': 'Folkestone Harbour',
#  'AddressLine2': 'Harbour Approach Road',
#  'AddressLine3': 'Folkestone',
#  'AddressLine4': 'Kent',
#  'BusinessName': 'Docker',
#  'BusinessType': 'Retailers - other',
#  'BusinessTypeID': 4613,
#  'ChangesByServerID': 0,
#  'Distance': 4591.914705329384,
#  'FHRSID': 894592,
#  'LocalAuthorityBusinessID': 'PI/000074396',
#  'LocalAuthorityCode': '188',
#  'LocalAuthorityEmailAddress': 'foodteam@folkestone-hythe.gov.uk',
#  'LocalAuthorityName': 'Folkestone and Hythe',
#  'LocalAuthorityWebSite': 'http://www.folkestone-hythe.gov.uk',
#  'NewRatingPending': False,
#  'Phone': '',
#  'PostCode': '',
#  'RatingDate': '2018-04-18T00:00:00',
#  'RatingKey': 'fhrs_5_en-gb',
#  'RatingValue': 5,
#  'RightToReply': '',
#  'SchemeType': 'FHRS',
#  '_id': ObjectId('664e9e0110d09d5d76f95605'),
#  'geocode': {'latitude': '51.0783519967076', 'longitude': '1.18590330311705'},
#  'latitude': 51.0783519967076,
#  'links': [{'href': 'https://api.ratings.food.gov.uk/establishments/894592',
#             'rel': 'self'}],
#  'longitude': 1.18590330311705,
#  'meta': {'dataSource': None,
#           'extractDate': '0001-01-01T00:00:00',
#           'itemCount': 0,
#           'pageNumber': 0,
#           'pageSize': 0,
#           'returncode': None,
#           'totalCount': 0,
#           'totalPages': 0},
#  'scores': {'ConfidenceInManagement': 5, 'Hygiene': 0, 'Structural': 0}}

# %%
# Convert result to Pandas DataFrame
df = pd.DataFrame(list(establishments.find(query).sort(sort).limit(limit)))
df
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  664e9e0110d09d5d76f95609  1423242                  0
# 1  664e9e0110d09d5d76f95640   511409                  0
# 2  664e9e0110d09d5d76f955fe   344689                  0
# 3  664e9e0110d09d5d76f955ff   289560                  0
# 4  664e9e0110d09d5d76f95605   894592                  0
#
#   LocalAuthorityBusinessID              BusinessName             BusinessType  \
# 0             PI/000078141               Little Rock  Other catering premises
# 1             PI/000039931              The Lifeboat        Pub/bar/nightclub
# 2             PI/000002095  Folkestone Trawlers Shop        Retailers - other
# 3             PI/000039927                   Mariner        Pub/bar/nightclub
# 4             PI/000074396                    Docker        Retailers - other
#
#    BusinessTypeID        AddressLine1           AddressLine2 AddressLine3  \
# 0            7841  Folkestone Harbour  Harbour Approach Road   Folkestone
# 1            7843     42 North Street             Folkestone         Kent
# 2            4613         1 The Stade             Folkestone         Kent
# 3            7843        16 The Stade             Folkestone         Kent
# 4            4613  Folkestone Harbour  Harbour Approach Road   Folkestone
#
#    ...                                             scores SchemeType  \
# 0  ...  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 1  ...  {'Hygiene': None, 'Structural': None, 'Confide...       FHRS
# 2  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 3  ...  {'Hygiene': 0, 'Structural': 5, 'ConfidenceInM...       FHRS
# 4  ...  {'Hygiene': 0, 'Structural': 0, 'ConfidenceInM...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '1.18590330311705', 'latitude': ...
# 1  {'longitude': '1.186715', 'latitude': '51.0815...
# 2  {'longitude': '1.188537', 'latitude': '51.08084'}
# 3  {'longitude': '1.188537', 'latitude': '51.08084'}
# 4  {'longitude': '1.18590330311705', 'latitude': ...
#
#       Distance NewRatingPending  \
# 0  4591.914705            False
# 1  4592.005042            False
# 2  4591.912145            False
# 3  4591.912145            False
# 4  4591.914705            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links   latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  51.078352  1.185903
# 1  [{'rel': 'self', 'href': 'https://api.ratings....  51.081546  1.186715
# 2  [{'rel': 'self', 'href': 'https://api.ratings....  51.080840  1.188537
# 3  [{'rel': 'self', 'href': 'https://api.ratings....  51.080840  1.188537
# 4  [{'rel': 'self', 'href': 'https://api.ratings....  51.078352  1.185903
#
# [5 rows x 30 columns]

# %% [markdown]
# ### 4. How many establishments in each Local Authority area have a hygiene score of 0?

# %%
# Create a pipeline that:
# 1. Matches establishments with a hygiene score of 0
# 2. Groups the matches by Local Authority
# 3. Sorts the matches from highest to lowest

# Print the number of documents in the result

# Print the first 10 results

pipeline = [
    {"$match": {"scores.Hygiene": 0}},
    {"$group": {"_id": "$LocalAuthorityName", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}}
]

result = list(establishments.aggregate(pipeline))

count_documents = establishments.count_documents({"scores.Hygiene": 0})
count_documents
# Out:
# 16827

# %%
for i in range(10):
    print(result[i])
# Out:
# {'_id': 'Thanet', 'count': 1130}
# {'_id': 'Greenwich', 'count': 882}
# {'_id': 'Maidstone', 'count': 713}
# {'_id': 'Newham', 'count': 711}
# {'_id': 'Swale', 'count': 686}
# {'_id': 'Chelmsford', 'count': 680}
# {'_id': 'Medway', 'count': 672}
# {'_id': 'Bexley', 'count': 607}
# {'_id': 'Southend-On-Sea', 'count': 586}
# {'_id': 'Tendring', 'count': 542}

# %%
# Convert the result to a Pandas DataFrame
results_df = pd.DataFrame(result)
result_df
# Out:
#                          _id   FHRSID  ChangesByServerID  \
# 0   664e9e0110d09d5d76f9713c   110681                  0
# 1   664e9e0110d09d5d76f974b5   612039                  0
# 2   664e9e0110d09d5d76f977b6   730933                  0
# 3   664e9e0110d09d5d76f9799f   172735                  0
# 4   664e9e0110d09d5d76f979c5   172953                  0
# 5   664e9e0110d09d5d76f9835c   512854                  0
# 6   664e9e0110d09d5d76f98572  1537089                  0
# 7   664e9e0110d09d5d76f99a9d   155648                  0
# 8   664e9e0110d09d5d76f99ee0  1012883                  0
# 9   664e9e0210d09d5d76f9a6f3   644109                  0
# 10  664e9e0210d09d5d76f9a764   267034                  0
# 11  664e9e0210d09d5d76f9ae18   972876                  0
# 12  664e9e0210d09d5d76f9b6e5  1417416                  0
# 13  664e9e0210d09d5d76f9bcf5  1384371                  0
# 14  664e9e0210d09d5d76f9c051   907216                  0
# 15  664e9e0210d09d5d76f9c5d3   710382                  0
# 16  664e9e0210d09d5d76f9c62f  1411729                  0
# 17  664e9e0210d09d5d76f9c88b  1060293                  0
# 18  664e9e0210d09d5d76f9ce6e  1243155                  0
# 19  664e9e0210d09d5d76f9d41c  1210197                  0
# 20  664e9e0210d09d5d76f9d43f   108663                  0
# 21  664e9e0210d09d5d76f9d712  1107748                  0
# 22  664e9e0210d09d5d76f9d74f   570096                  0
# 23  664e9e0210d09d5d76f9d85f  1500698                  0
# 24  664e9e0210d09d5d76f9d91e  1318114                  0
# 25  664e9e0210d09d5d76f9d92a  1498084                  0
# 26  664e9e0210d09d5d76f9da18  1063454                  0
# 27  664e9e0210d09d5d76f9da90  1130121                  0
# 28  664e9e0210d09d5d76f9dcd9   640363                  0
# 29  664e9e0210d09d5d76f9dd26   640816                  0
# 30  664e9e0210d09d5d76f9dd96  1530599                  0
# 31  664e9e0210d09d5d76f9dea5   668674                  0
# 32  664e9e0210d09d5d76f9df8f  1286585                  0
# 33  664e9e0210d09d5d76f9e042   971735                  0
# 34  664e9e0210d09d5d76f9e1e7  1055935                  0
# 35  664e9e0210d09d5d76f9e374  1177878                  0
# 36  664e9e0210d09d5d76f9e460  1296829                  0
# 37  664e9e0210d09d5d76f9e7d7   514573                  0
# 38  664e9e0210d09d5d76f9e9cf   124507                  0
# 39  664e9e0210d09d5d76f9ebea   479001                  0
# 40  664e9e0210d09d5d76f9edee   107710                  0
#
#    LocalAuthorityBusinessID  \
# 0                      4029
# 1                 1970/FOOD
# 2                 1698/FOOD
# 3              PI/000023858
# 4              PI/000024532
# 5             12/00816/BUTH
# 6           22/00224/RESTUN
# 7               EH/00006058
# 8          17/00110/MIXED/S
# 9                     41811
# 10           11/00102/MIXED
# 11          17/00059/FOOD/S
# 12              21/00350/CP
# 13           21/00062/MIXED
# 14                   132648
# 15             PI/000194267
# 16           21/00562/MIXED
# 17             PI/000206588
# 18                    75460
# 19                    75196
# 20                    38915
# 21            19/00222/FOOD
# 22                   178447
# 23                   201759
# 24                   200845
# 25            22/00797/FOOD
# 26            18/00285/FOOD
# 27            19/00249/FOOD
# 28            10/00269/FOOD
# 29         61130/0282/0/000
# 30            22/01037/FOOD
# 31             14/00082/COM
# 32            20/00532/FOOD
# 33             17/00076/COM
# 34            18/00198/FOOD
# 35                   347294
# 36                   347449
# 37                    44243
# 38              53022999151
# 39             12/00162/COM
# 40              38127001007
#
#                                          BusinessName  \
# 0                                 The Chase Rest Home
# 1                                          Brenalwood
# 2                                       Melrose Hotel
# 3                                       Seaford Pizza
# 4                                       Golden Palace
# 5                                    Ashby's Butchers
# 6                           South Sea Express Cuisine
# 7                                       Golden Palace
# 8                                      The Tulip Tree
# 9                                               F & S
# 10                                          Longhouse
# 11  Westview Playgroup Based At Downsview Comm Pri...
# 12                        Whatever The Weather Coffee
# 13                        Kings Restaurant (Oriental)
# 14                                            Xich Lo
# 15      Asian Supermarket Ltd: T/A Best Food Wine Ltd
# 16                                             Londis
# 17                                         Costcutter
# 18                                       La Simon Ltd
# 19                                     Caribiscus Ltd
# 20                              Kennedy Fried Chicken
# 21                                          Gah Shing
# 22                                     A1 News & Wine
# 23                                      Cakes & Bakes
# 24                        Sahajanand Catering Limited
# 25                                         Sisko Cafe
# 26                             Magazin Romanesc Diana
# 27                                      Bali Maamalas
# 28                                      Angels Bakery
# 29                            Nikkis Place Restaurant
# 30                                         Chicago 30
# 31                              Samui Thai Restaurant
# 32                            Pakhtoonkhwa Restaurant
# 33                                   New Happy Garden
# 34                                          Mummy Yum
# 35                                          Gospodina
# 36                                  Leo's Bar & Grill
# 37                                         Royal Ribs
# 38                      Great Hallingbury Manor Hotel
# 39                                   The Dog And Duck
# 40                                   Oriental Cottage
#
#                          BusinessType  BusinessTypeID  \
# 0                     Caring Premises               5
# 1                     Caring Premises               5
# 2   Hotel/bed & breakfast/guest house            7842
# 3              Takeaway/sandwich shop            7844
# 4             Restaurant/Cafe/Canteen               1
# 5                   Retailers - other            4613
# 6             Restaurant/Cafe/Canteen               1
# 7              Takeaway/sandwich shop            7844
# 8             Restaurant/Cafe/Canteen               1
# 9                   Retailers - other            4613
# 10            Restaurant/Cafe/Canteen               1
# 11            Other catering premises            7841
# 12                     Mobile caterer            7846
# 13             Takeaway/sandwich shop            7844
# 14            Restaurant/Cafe/Canteen               1
# 15                  Retailers - other            4613
# 16                  Retailers - other            4613
# 17                  Retailers - other            4613
# 18                  Retailers - other            4613
# 19            Restaurant/Cafe/Canteen               1
# 20             Takeaway/sandwich shop            7844
# 21             Takeaway/sandwich shop            7844
# 22                  Retailers - other            4613
# 23             Takeaway/sandwich shop            7844
# 24            Restaurant/Cafe/Canteen               1
# 25            Restaurant/Cafe/Canteen               1
# 26                  Retailers - other            4613
# 27            Restaurant/Cafe/Canteen               1
# 28            Other catering premises            7841
# 29            Restaurant/Cafe/Canteen               1
# 30             Takeaway/sandwich shop            7844
# 31            Restaurant/Cafe/Canteen               1
# 32            Restaurant/Cafe/Canteen               1
# 33             Takeaway/sandwich shop            7844
# 34             Takeaway/sandwich shop            7844
# 35                  Retailers - other            4613
# 36            Restaurant/Cafe/Canteen               1
# 37             Takeaway/sandwich shop            7844
# 38            Restaurant/Cafe/Canteen               1
# 39                  Pub/bar/nightclub            7843
# 40             Takeaway/sandwich shop            7844
#
#                           AddressLine1               AddressLine2  \
# 0                 5-6 Southfields Road                 Eastbourne
# 1                            Hall Lane         Walton-on-the-Naze
# 2                53 Marine Parade East             Clacton On Sea
# 3                        4 High Street                    Seaford
# 4                       5 South Street                    Seaford
# 5                 777 Southchurch Road            Southend-On-Sea
# 6                  33 Alexandra Street            Southend-on-sea
# 7                        7 London Road                   Rayleigh
# 8                        3 The Village              Chiddingstone
# 9                                                  81 Southernhay
# 10                      17 London Road                  Riverhead
# 11  Downsview Community Primary School               Beech Avenue
# 12                           EMR Erith                 Manor Road
# 13                       43 Kings Road                  Brentwood
# 14                     24 Station Lane                 Hornchurch
# 15                 2 - 6 Basildon Road
# 16                5 - 7 Cranley Parade          Beaconsfield Road
# 17                         2 The Slade
# 18                                               8 Porters Avenue
# 19                                             87 Longbridge Road
# 20                                              66 Station Parade
# 21                 5 High Street South                   East Ham
# 22                                                221 Ilford Lane
# 23                                                108 Ilford Lane
# 24                                                 149 Ley Street
# 25              151 - 153 Barking Road                   East Ham
# 26               221 High Street North                   East Ham
# 27              241B High Street North                 Manor Park
# 28                    333 Barking Road                   Plaistow
# 29                    282 Barking Road                   Plaistow
# 30                  369 Katherine Road                Forest Gate
# 31                          The Kinema            Chelmsford Road
# 32                     76 Green Street                Forest Gate
# 33                   23 Stortford Road                     Dunmow
# 34                    34 West Ham Lane                  Stratford
# 35                                      345 High Road Leytonstone
# 36                                                 32 Church Lane
# 37                                                  14 Hatch Lane
# 38             Great Hallingbury Manor             Tilekiln Green
# 39                     58 Lower Street                   Stansted
# 40                       1 Mercers Row             Saffron Walden
#
#          AddressLine3  ...                                             scores  \
# 0         East Sussex  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 1               Essex  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 2               Essex  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 3         East Sussex  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 4         East Sussex  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 5               Essex  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 6               Essex  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 7               Essex  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 8                KENT  ...  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# 9            Basildon  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 10               KENT  ...  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...
# 11            Swanley  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 12              Erith  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 13              Essex  ...  {'Hygiene': 20, 'Structural': 25, 'ConfidenceI...
# 14                     ...  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# 15         Abbey Wood  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 16         Mottingham  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 17          Plumstead  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 18                     ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 19                     ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 20                     ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 21             London  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 22                     ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 23                     ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 24                     ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 25             London  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 26             London  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 27             London  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 28             London  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 29             London  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 30             London  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 31             Dunmow  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 32             London  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 33                     ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 34             London  ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 35                     ...  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...
# 36                     ...  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...
# 37                     ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 38  Great Hallingbury  ...  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...
# 39              Essex  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
# 40              Essex  ...  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...
#
#    SchemeType                                            geocode  \
# 0        FHRS  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1        FHRS  {'longitude': '1.278721', 'latitude': '51.8575...
# 2        FHRS  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3        FHRS  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4        FHRS  {'longitude': '0.101446', 'latitude': '50.7707...
# 5        FHRS  {'longitude': '0.736349', 'latitude': '51.5414...
# 6        FHRS  {'longitude': '0.7121671', 'latitude': '51.535...
# 7        FHRS  {'longitude': '0.602364', 'latitude': '51.5915...
# 8        FHRS  {'longitude': '0.146449998021126', 'latitude':...
# 9        FHRS  {'longitude': '0.462307', 'latitude': '51.57005'}
# 10       FHRS  {'longitude': '0.169685', 'latitude': '51.2847...
# 11       FHRS  {'longitude': '0.1864034', 'latitude': '51.395...
# 12       FHRS  {'longitude': '0.19265740017645', 'latitude': ...
# 13       FHRS   {'longitude': '0.2983', 'latitude': '51.618135'}
# 14       FHRS  {'longitude': '0.220507', 'latitude': '51.5612...
# 15       FHRS  {'longitude': '0.1070469', 'latitude': '51.484...
# 16       FHRS  {'longitude': '0.0460971', 'latitude': '51.427...
# 17       FHRS  {'longitude': '0.0888789', 'latitude': '51.480...
# 18       FHRS  {'longitude': '0.1300921', 'latitude': '51.551...
# 19       FHRS  {'longitude': '0.084452', 'latitude': '51.5417...
# 20       FHRS  {'longitude': '0.081616', 'latitude': '51.5392...
# 21       FHRS  {'longitude': '0.055764', 'latitude': '51.5313...
# 22       FHRS  {'longitude': '0.074347', 'latitude': '51.5516...
# 23       FHRS  {'longitude': '0.0725645', 'latitude': '51.554...
# 24       FHRS  {'longitude': '0.077645', 'latitude': '51.5622...
# 25       FHRS  {'longitude': '0.046878', 'latitude': '51.5319...
# 26       FHRS  {'longitude': '0.050713', 'latitude': '51.53963'}
# 27       FHRS  {'longitude': '0.050334', 'latitude': '51.5411...
# 28       FHRS  {'longitude': '0.021028', 'latitude': '51.52189'}
# 29       FHRS  {'longitude': '0.018342', 'latitude': '51.5201...
# 30       FHRS  {'longitude': '0.037523', 'latitude': '51.5416...
# 31       FHRS  {'longitude': '0.3659018', 'latitude': '51.868...
# 32       FHRS  {'longitude': '0.031959', 'latitude': '51.5439...
# 33       FHRS  {'longitude': '0.360846', 'latitude': '51.8730...
# 34       FHRS  {'longitude': '0.004389', 'latitude': '51.5388...
# 35       FHRS  {'longitude': '0.005407', 'latitude': '51.5557...
# 36       FHRS  {'longitude': '0.009101', 'latitude': '51.5682...
# 37       FHRS  {'longitude': '0.006248', 'latitude': '51.61912'}
# 38       FHRS  {'longitude': '0.207771003246307', 'latitude':...
# 39       FHRS  {'longitude': '0.201087', 'latitude': '51.9040...
# 40       FHRS  {'longitude': '0.240491', 'latitude': '52.02328'}
#
#     RightToReply     Distance NewRatingPending  \
# 0                 4613.888288            False
# 1                 4617.965824            False
# 2                 4619.656144            False
# 3                 4620.421725            False
# 4                 4620.437179            False
# 5                 4625.565258            False
# 6                 4626.200132            False
# 7                 4632.276890            False
# 8                 4633.934041            False
# 9                 4636.552523            False
# 10                4636.703065            False
# 11                4640.152449            False
# 12                4642.935252            False
# 13                4644.277277            False
# 14                4645.006441            False
# 15                4646.327125            False
# 16                4646.448256             True
# 17                4646.814122            False
# 18                4647.937955            False
# 19                4649.237462            False
# 20                4649.251920            False
# 21                4649.903794            False
# 22                4649.968842            False
# 23                4650.123644            False
# 24                4650.239432            False
# 25                4650.247785            False
# 26                4650.389971            False
# 27                4650.459698            False
# 28                4650.822100            False
# 29                4650.856226            False
# 30                4650.944835            False
# 31                4651.099995            False
# 32                4651.233130            False
# 33                4651.444488            False
# 34                4652.049760            False
# 35                4652.632190            False
# 36                4652.953922             True
# 37                4654.920996            False
# 38                4656.798774            False
# 39                4658.344880            False
# 40                4661.334349            False
#
#                                                  meta  \
# 0   {'dataSource': None, 'extractDate': '0001-01-0...
# 1   {'dataSource': None, 'extractDate': '0001-01-0...
# 2   {'dataSource': None, 'extractDate': '0001-01-0...
# 3   {'dataSource': None, 'extractDate': '0001-01-0...
# 4   {'dataSource': None, 'extractDate': '0001-01-0...
# 5   {'dataSource': None, 'extractDate': '0001-01-0...
# 6   {'dataSource': None, 'extractDate': '0001-01-0...
# 7   {'dataSource': None, 'extractDate': '0001-01-0...
# 8   {'dataSource': None, 'extractDate': '0001-01-0...
# 9   {'dataSource': None, 'extractDate': '0001-01-0...
# 10  {'dataSource': None, 'extractDate': '0001-01-0...
# 11  {'dataSource': None, 'extractDate': '0001-01-0...
# 12  {'dataSource': None, 'extractDate': '0001-01-0...
# 13  {'dataSource': None, 'extractDate': '0001-01-0...
# 14  {'dataSource': None, 'extractDate': '0001-01-0...
# 15  {'dataSource': None, 'extractDate': '0001-01-0...
# 16  {'dataSource': None, 'extractDate': '0001-01-0...
# 17  {'dataSource': None, 'extractDate': '0001-01-0...
# 18  {'dataSource': None, 'extractDate': '0001-01-0...
# 19  {'dataSource': None, 'extractDate': '0001-01-0...
# 20  {'dataSource': None, 'extractDate': '0001-01-0...
# 21  {'dataSource': None, 'extractDate': '0001-01-0...
# 22  {'dataSource': None, 'extractDate': '0001-01-0...
# 23  {'dataSource': None, 'extractDate': '0001-01-0...
# 24  {'dataSource': None, 'extractDate': '0001-01-0...
# 25  {'dataSource': None, 'extractDate': '0001-01-0...
# 26  {'dataSource': None, 'extractDate': '0001-01-0...
# 27  {'dataSource': None, 'extractDate': '0001-01-0...
# 28  {'dataSource': None, 'extractDate': '0001-01-0...
# 29  {'dataSource': None, 'extractDate': '0001-01-0...
# 30  {'dataSource': None, 'extractDate': '0001-01-0...
# 31  {'dataSource': None, 'extractDate': '0001-01-0...
# 32  {'dataSource': None, 'extractDate': '0001-01-0...
# 33  {'dataSource': None, 'extractDate': '0001-01-0...
# 34  {'dataSource': None, 'extractDate': '0001-01-0...
# 35  {'dataSource': None, 'extractDate': '0001-01-0...
# 36  {'dataSource': None, 'extractDate': '0001-01-0...
# 37  {'dataSource': None, 'extractDate': '0001-01-0...
# 38  {'dataSource': None, 'extractDate': '0001-01-0...
# 39  {'dataSource': None, 'extractDate': '0001-01-0...
# 40  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                 links   latitude longitude
# 0   [{'rel': 'self', 'href': 'https://api.ratings....  50.769705  0.276940
# 1   [{'rel': 'self', 'href': 'https://api.ratings....  51.857536  1.278721
# 2   [{'rel': 'self', 'href': 'https://api.ratings....  51.789429  1.159270
# 3   [{'rel': 'self', 'href': 'https://api.ratings....  50.770885  0.102020
# 4   [{'rel': 'self', 'href': 'https://api.ratings....  50.770724  0.101446
# 5   [{'rel': 'self', 'href': 'https://api.ratings....  51.541448  0.736349
# 6   [{'rel': 'self', 'href': 'https://api.ratings....  51.535007  0.712167
# 7   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.591515  0.602364
# 8   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.185947  0.146450
# 9   [{'rel': 'self', 'href': 'http://api.ratings.f...  51.570050  0.462307
# 10  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.284795  0.169685
# 11  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.395469  0.186403
# 12  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.477426  0.192657
# 13  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.618135  0.298300
# 14  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.561287  0.220507
# 15  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.484815  0.107047
# 16  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.427399  0.046097
# 17  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.480027  0.088879
# 18  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.551579  0.130092
# 19  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.541715  0.084452
# 20  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.539293  0.081616
# 21  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.531385  0.055764
# 22  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.551624  0.074347
# 23  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.554076  0.072565
# 24  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.562276  0.077645
# 25  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.531936  0.046878
# 26  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.539630  0.050713
# 27  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.541156  0.050334
# 28  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.521890  0.021028
# 29  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.520147  0.018342
# 30  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.541658  0.037523
# 31  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.868671  0.365902
# 32  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.543994  0.031959
# 33  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.873055  0.360846
# 34  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.538857  0.004389
# 35  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.555782  0.005407
# 36  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.568245  0.009101
# 37  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.619120  0.006248
# 38  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.868683  0.207771
# 39  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.904039  0.201087
# 40  [{'rel': 'self', 'href': 'http://api.ratings.f...  52.023280  0.240491
#
# [41 rows x 30 columns]

# %%
# Display the number of rows in the DataFrame
len(result_df)
# Out:
# 41

# %%
# Display the first 10 rows of the DataFrame
result_df.head(10)
# Out:
#                         _id   FHRSID  ChangesByServerID  \
# 0  664e9e0110d09d5d76f9713c   110681                  0
# 1  664e9e0110d09d5d76f974b5   612039                  0
# 2  664e9e0110d09d5d76f977b6   730933                  0
# 3  664e9e0110d09d5d76f9799f   172735                  0
# 4  664e9e0110d09d5d76f979c5   172953                  0
# 5  664e9e0110d09d5d76f9835c   512854                  0
# 6  664e9e0110d09d5d76f98572  1537089                  0
# 7  664e9e0110d09d5d76f99a9d   155648                  0
# 8  664e9e0110d09d5d76f99ee0  1012883                  0
# 9  664e9e0210d09d5d76f9a6f3   644109                  0
#
#   LocalAuthorityBusinessID               BusinessName  \
# 0                     4029        The Chase Rest Home
# 1                1970/FOOD                 Brenalwood
# 2                1698/FOOD              Melrose Hotel
# 3             PI/000023858              Seaford Pizza
# 4             PI/000024532              Golden Palace
# 5            12/00816/BUTH           Ashby's Butchers
# 6          22/00224/RESTUN  South Sea Express Cuisine
# 7              EH/00006058              Golden Palace
# 8         17/00110/MIXED/S             The Tulip Tree
# 9                    41811                      F & S
#
#                         BusinessType  BusinessTypeID           AddressLine1  \
# 0                    Caring Premises               5   5-6 Southfields Road
# 1                    Caring Premises               5              Hall Lane
# 2  Hotel/bed & breakfast/guest house            7842  53 Marine Parade East
# 3             Takeaway/sandwich shop            7844          4 High Street
# 4            Restaurant/Cafe/Canteen               1         5 South Street
# 5                  Retailers - other            4613   777 Southchurch Road
# 6            Restaurant/Cafe/Canteen               1    33 Alexandra Street
# 7             Takeaway/sandwich shop            7844          7 London Road
# 8            Restaurant/Cafe/Canteen               1          3 The Village
# 9                  Retailers - other            4613
#
#          AddressLine2 AddressLine3  ...  \
# 0          Eastbourne  East Sussex  ...
# 1  Walton-on-the-Naze        Essex  ...
# 2      Clacton On Sea        Essex  ...
# 3             Seaford  East Sussex  ...
# 4             Seaford  East Sussex  ...
# 5     Southend-On-Sea        Essex  ...
# 6     Southend-on-sea        Essex  ...
# 7            Rayleigh        Essex  ...
# 8       Chiddingstone         KENT  ...
# 9      81 Southernhay     Basildon  ...
#
#                                               scores SchemeType  \
# 0  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 1  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 2  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 3  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 4  {'Hygiene': 20, 'Structural': 10, 'ConfidenceI...       FHRS
# 5  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 6  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
# 7  {'Hygiene': 20, 'Structural': 15, 'ConfidenceI...       FHRS
# 8  {'Hygiene': 20, 'Structural': 5, 'ConfidenceIn...       FHRS
# 9  {'Hygiene': 20, 'Structural': 20, 'ConfidenceI...       FHRS
#
#                                              geocode  RightToReply  \
# 0  {'longitude': '0.27694', 'latitude': '50.769705'}
# 1  {'longitude': '1.278721', 'latitude': '51.8575...
# 2  {'longitude': '1.15927', 'latitude': '51.789429'}
# 3  {'longitude': '0.10202', 'latitude': '50.770885'}
# 4  {'longitude': '0.101446', 'latitude': '50.7707...
# 5  {'longitude': '0.736349', 'latitude': '51.5414...
# 6  {'longitude': '0.7121671', 'latitude': '51.535...
# 7  {'longitude': '0.602364', 'latitude': '51.5915...
# 8  {'longitude': '0.146449998021126', 'latitude':...
# 9  {'longitude': '0.462307', 'latitude': '51.57005'}
#
#       Distance NewRatingPending  \
# 0  4613.888288            False
# 1  4617.965824            False
# 2  4619.656144            False
# 3  4620.421725            False
# 4  4620.437179            False
# 5  4625.565258            False
# 6  4626.200132            False
# 7  4632.276890            False
# 8  4633.934041            False
# 9  4636.552523            False
#
#                                                 meta  \
# 0  {'dataSource': None, 'extractDate': '0001-01-0...
# 1  {'dataSource': None, 'extractDate': '0001-01-0...
# 2  {'dataSource': None, 'extractDate': '0001-01-0...
# 3  {'dataSource': None, 'extractDate': '0001-01-0...
# 4  {'dataSource': None, 'extractDate': '0001-01-0...
# 5  {'dataSource': None, 'extractDate': '0001-01-0...
# 6  {'dataSource': None, 'extractDate': '0001-01-0...
# 7  {'dataSource': None, 'extractDate': '0001-01-0...
# 8  {'dataSource': None, 'extractDate': '0001-01-0...
# 9  {'dataSource': None, 'extractDate': '0001-01-0...
#
#                                                links   latitude longitude
# 0  [{'rel': 'self', 'href': 'https://api.ratings....  50.769705  0.276940
# 1  [{'rel': 'self', 'href': 'https://api.ratings....  51.857536  1.278721
# 2  [{'rel': 'self', 'href': 'https://api.ratings....  51.789429  1.159270
# 3  [{'rel': 'self', 'href': 'https://api.ratings....  50.770885  0.102020
# 4  [{'rel': 'self', 'href': 'https://api.ratings....  50.770724  0.101446
# 5  [{'rel': 'self', 'href': 'https://api.ratings....  51.541448  0.736349
# 6  [{'rel': 'self', 'href': 'https://api.ratings....  51.535007  0.712167
# 7  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.591515  0.602364
# 8  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.185947  0.146450
# 9  [{'rel': 'self', 'href': 'http://api.ratings.f...  51.570050  0.462307
#
# [10 rows x 30 columns]
